# %% [markdown]
# # In this tutorial, you will learn how to develop a Machine Learning classifier for the automatic detection of handwritten digits.
#
# # The challenge of handwritten digit classification in machine learning revolves around the creation of algorithms and models designed to accurately identify and assign labels to handwritten digits. Throughout this tutorial, we will primarily utilize the scikit-learn (sklearn) library for this purpose.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Load the MNIST dataset
digits = datasets.load_digits()

# %%
# Split the data into features and labels
X = digits.images
y = digits.target

# %%
X = digits['images']
y = digits['target']

print(f'Images (x) Shape : {X.shape}')
print(f'Target (y) Shape : {y.shape}')
# Out:
# Images (x) Shape : (1797, 8, 8)
# Target (y) Shape : (1797,)

# %%
# Display sample data
plt.imshow(X[9], cmap=plt.cm.gray )
print(f'True  Value: {y[9]}')
# Out:
# True  Value: 9

# %%
#
# Your code to display any other sample image and its true value.
#

# %% [markdown]
# The following plot prints a bunch of digits. However, the X-axis of the subplot looks a bit messy from the second row. Improve the plot to make it look better.

# %%
# Display sample data i.e. a bunch of images.
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.imshow(X[i], cmap=plt.cm.gray )
    plt.title(f"True: {y[i]}")

plt.show()

# %%
# Flatten the images into a 1D array
n_samples = len(X)
X = X.reshape((n_samples, -1))

# %%
# Split the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
# Flatten the images into a 1D array
n_samples = len(X)
X = X.reshape((n_samples, -1))

# %%
# Create an MLP classifier with 2 hidden layers with 100 neurons in each layer
clf = MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
# Train the classifier on the training data
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
# Make predictions on the test data
y_pred = clf.predict(X_test)

# %%
# Calculate the accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred) * 100
print(f'Accuracy: {accuracy :.2f}%')
# Out:
# Accuracy: 97.33%

# %%
# Generate a classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        89
#            1       0.94      0.98      0.96        90
#            2       0.99      0.97      0.98        92
#            3       1.00      0.97      0.98        93
#            4       0.97      0.99      0.98        76
#            5       0.95      0.98      0.97       108
#            6       0.96      0.98      0.97        89
#            7       0.96      1.00      0.98        78
#            8       0.98      0.89      0.93        92
#            9       0.99      0.99      0.99        92
#
#     accuracy                           0.97       899
#    macro avg       0.97      0.97      0.97       899
# weighted avg       0.97      0.97      0.97       899

# %%
# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()

# %% [markdown]
# # Next, try three other different MLP models with various configurations, such as the number of hidden layers, the number of neurons in each hidden layer, different learning rates, different numbers of iterations to train the model, or different optimization functions.
#
# #Use the configuration of your choice.
#
# # Use the MLPClassifier() class from scikit-learn, which you can find here: https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html .
#
# # You should store the accuracy of each model in a separate variable or a list.
#
# # Create a bar graph comparing the accuracy of all the models. To do this, you can use the 'barh' class from the Python pyplot library, which is explained here:
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.barh.html
#
# # **Important -** Document in your lab logbook:
#
# # 1. The output of the neural network model provided in task 1.
# # 2. A bar plot comparing the accuracy of the different MLP models from your code.

# %%
#
# Your code to compare the different models and bar plot comparing model accuracy.
# You can split your code in multiple cells
#
modelName = ['clf', 'E1', 'e2', 'e3']
#models = [clf, UBG, ebong, etim]
accuracies = [accuracy, accuracy1, accuracy2, accuracy3]
print(modelName)
print(accuracies)
# You can split your code in multiple cells
plt.barh(modelName, accuracies, color=['brown', 'orange', 'yellow', 'blue'])
#

# %%
#code to split dataset into traininng and test data on model 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
# code to flatten the images into a 1D array
n_samples = len(X)
X = X.reshape((n_samples, -1))

# %%
# Code to create an MLP classifier with 2 hidden layers with 100 neurons in each layer for model 1
E1 = MLPClassifier(hidden_layer_sizes=(100,  100, 100), activation ='relu', alpha = 0.25, max_iter=2000)

# %%
# code to train the classifier on the training data
E1.fit(X_train, y_train)
# Out:
# MLPClassifier(alpha=0.25, hidden_layer_sizes=(100, 100, 100), max_iter=2000)

# %%
# code to make predictions on test data 
y_pred1 = E1.predict(X_test)

# %%
# Calculate the accuracy of the classifier
accuracy1 = accuracy_score(y_test, y_pred1) * 100
print(f'Accuracy: {accuracy1 :.2f}%')
# Out:
# Accuracy: 96.67%

# %%
#code to split dataset into traininng and test data on model 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=0)

# %%
# code to flatten the images into a 1D array
n_samples = len(X)
X = X.reshape((n_samples, -1))

# %%
# model 2
# Code to create an MLP classifier with 2 hidden layers with 100 neurons in each layer for model 1
e2 = MLPClassifier(hidden_layer_sizes=(100, 200, 100), activation ='logistic', alpha = 0.02, max_iter=500)

# %%
# code to train the classifier on the training data
e2.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.02,
#               hidden_layer_sizes=(100, 200, 100), max_iter=500)

# %%
# code to make predictions on test data 
y_pred2 = e2.predict(X_test)

# %%
# Calculate the accuracy of the classifier
accuracy2 = accuracy_score(y_test, y_pred2) * 100
print(f'Accuracy: {accuracy2 :.2f}%')
# Out:
# Accuracy: 95.64%

# %%
# model 3
# Code to create an MLP classifier with 2 hidden layers with 100 neurons in each layer for model 1
e3 = MLPClassifier(hidden_layer_sizes=(100, 200,100,50, 50), activation ='relu', alpha = 0.007, max_iter=7000)

# %%
# code to train the classifier on the training data
e3.fit(X_train, y_train)
# Out:
# MLPClassifier(alpha=0.007, hidden_layer_sizes=(100, 200, 100, 50, 50),
#               max_iter=7000)

# %%
# code to make predictions on test data 
y_pred3 = e3.predict(X_test)

# %%
# Calculate the accuracy of the classifier
accuracy3 = accuracy_score(y_test, y_pred3) * 100
print(f'Accuracy: {accuracy3  :.2f}%')
# Out:
# Accuracy: 96.94%

# %%
#
# Your code to compare the different models and bar plot comparing model accuracy.
modelName = ['clf', 'E1', 'e2', 'e3']
#models = [clf, UBG, ebong, etim]
accuracies = [accuracy, accuracy1, accuracy2, accuracy3]
print(modelName)
print(accuracies)
# You can split your code in multiple cells
plt.barh(modelName, accuracies, color=['brown', 'orange', 'yellow', 'blue'])
#
# Out:
# ['clf', 'E1', 'e2', 'e3']
# [97.33036707452726, 96.66666666666667, 95.64411492122335, 96.9416126042632]
# <BarContainer object of 4 artists>

# %% [markdown]
# # Write code to display 10 images from X_test, along with their true values and predicted values for any MLP model. Your plot should resemble the following:
#
# # Hint: You'll need to use the 'reshape' function.
#
# ![image.png](data:image/png;base64,...)

# %%
#
#
#  Your code to display the above plot
#

# %%
X_test_images = X_test.reshape(-1, 8,8)

# Choose 10 random images from the test set
indices = np.random.choice(range(len(X_test)), size=10, replace=False)


ig, axes = plt.subplots(2, 5, figsize=(15, 6))

for i, idx in enumerate(indices):
    # Display the image
    axes[i//5, i%5].imshow(X_test_images[idx], cmap='gray')
    
    # Set the title to the true and predicted labels
    axes[i//5, i%5].set_title(f'True: {y_test[idx]}\nPredicted: {y_pred[idx]}')

#

plt.show()
